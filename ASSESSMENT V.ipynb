# %%
#Importing Relevant Python  Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading the csv file

CarSales=pd.read_csv('Car-sales.csv')

# %%
#Showing the loaded csv file

CarSales
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %% [markdown]
# # Understanding the Dataset/Data Cleaning

# %%
#Question 1 
#Identifying the Number of Rows and Columns in the dataset

Number_of_Rows= CarSales.shape[0]
Number_of_Columns= CarSales.shape[1]

# %%
#Printing the Number of Rows and Columns in the dataset

print(f"Number of Rows: {Number_of_Rows}")
print(f"Number of Columns: {Number_of_Columns}")
# Out:
# Number of Rows: 157
# Number of Columns: 16

# %%
#Question 2 
#Identifying the Data Type of each column

CarSales.dtypes
# Out:
# Manufacturer            object
# Model                   object
# Sales_in_thousands     float64
# __year_resale_value    float64
# Vehicle_type            object
# Price_in_thousands     float64
# Engine_size            float64
# Horsepower             float64
# Wheelbase              float64
# Width                  float64
# Length                 float64
# Curb_weight            float64
# Fuel_capacity          float64
# Fuel_efficiency        float64
# Latest_Launch           object
# Power_perf_factor      float64
# dtype: object

# %%
#Question 3
#Counting any missing values in the dataset

CarSales.isna().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Vehicle_type            0
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# dtype: int64

# %%
# Filling the missing values in the 'year_resale_value' column with the it's average value (Hint: Find the Average of the column first)

Avg=CarSales['__year_resale_value'].mean()

Avg
# Out:
# 18.072975206611574

# %%
#Replacing the Missing Values with the average calculated (18.072975206611574)

CarSales['__year_resale_value'].replace(np.nan, Avg, inplace=True )

# %%
#Printing the dataset to see the changes

CarSales
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919            16.360000
# 1          Acura       TL              39.384            19.875000
# 2          Acura       CL              14.114            18.225000
# 3          Acura       RL               8.588            29.725000
# 4           Audi       A4              20.397            22.255000
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545            18.072975
# 153        Volvo      S70              15.245            18.072975
# 154        Volvo      V70              17.531            18.072975
# 155        Volvo      C70               3.493            18.072975
# 156        Volvo      S80              18.969            18.072975
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
#Dropping other rows with missing values

CarSales.dropna(inplace=True)

# %%
#Displaying the dataset to see the changes

CarSales
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919            16.360000
# 1          Acura       TL              39.384            19.875000
# 3          Acura       RL               8.588            29.725000
# 4           Audi       A4              20.397            22.255000
# 5           Audi       A6              18.780            23.555000
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545            18.072975
# 153        Volvo      S70              15.245            18.072975
# 154        Volvo      V70              17.531            18.072975
# 155        Volvo      C70               3.493            18.072975
# 156        Volvo      S80              18.969            18.072975
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
#Question 4 
#Cleaning Column four (4) to remove the underscores (Hint:Rename the Column)

CarSales.rename(columns={'__year_resale_value':'Year Resale Value'}, inplace=True)

# %%
#Display the dataset to see the effect

CarSales
# Out:
#     Manufacturer    Model  Sales_in_thousands  Year Resale Value Vehicle_type  \
# 0          Acura  Integra              16.919          16.360000    Passenger
# 1          Acura       TL              39.384          19.875000    Passenger
# 3          Acura       RL               8.588          29.725000    Passenger
# 4           Audi       A4              20.397          22.255000    Passenger
# 5           Audi       A6              18.780          23.555000    Passenger
# ..           ...      ...                 ...                ...          ...
# 152        Volvo      V40               3.545          18.072975    Passenger
# 153        Volvo      S70              15.245          18.072975    Passenger
# 154        Volvo      V70              17.531          18.072975    Passenger
# 155        Volvo      C70               3.493          18.072975    Passenger
# 156        Volvo      S80              18.969          18.072975    Passenger
#
# ...

# %%
#Describing the dataset
#Carrying out some measures of central tendency on the numerical columns(Hint: Find the Mean, Median and Standard Deviation)

CarSales.describe()
# Out:
#        Sales_in_thousands  Year Resale Value  Price_in_thousands  Engine_size  \
# count          152.000000         152.000000          152.000000   152.000000
# mean            53.359072          18.041080           27.331822     3.049342
# std             68.938380          10.172085           14.418669     1.049818
# min              0.110000           5.160000            9.235000     1.000000
# 25%             13.714000          12.527500           17.888750     2.300000
# 50%             29.213000          17.425000           22.747000     3.000000
# 75%             68.069750          18.072975           31.938750     3.575000
# max            540.561000          67.550000           85.500000     8.000000
#
#        Horsepower   Wheelbase       Width      Length  Curb_weight  \
# count  152.000000  152.000000  152.000000  152.000000   152.000000
# mean   184.809211  107.413816   71.088816  187.059211     3.376184
# ...

# %%
#Question 5
#Checking for duplicates
CarSales.duplicated()
# Out:
# 0      False
# 1      False
# 3      False
# 4      False
# 5      False
#        ...
# 152    False
# 153    False
# 154    False
# 155    False
# 156    False
# Length: 152, dtype: bool

# %%
#No Duplicates

# %% [markdown]
# # SPECIFIC ANALYSIS

# %%
#6.Checking for the manufacturer with the highest and lowest average sales volume

Average_sales_volume=CarSales.groupby('Manufacturer')['Sales_in_thousands'].mean()
Average_sales_volume
# Out:
# Manufacturer
# Acura          21.630333
# Audi           13.519000
# BMW            15.501667
# Buick          60.504750
# Cadillac       24.058750
# Chevrolet      61.596111
# Chrysler       24.706833
# Dodge          82.212100
# Ford          183.875909
# Honda         118.534800
# Hyundai        45.775333
# Infiniti       23.713000
# Jaguar         15.467000
# Jeep           97.717667
# Lexus          17.807167
# Lincoln        28.544667
# Mercedes-B     13.013889
# Mercury        39.666500
# Mitsubishi     25.842143
# Nissan         57.090714
# Oldsmobile     28.087000
# Plymouth       16.000250
# Pontiac        61.755667
# Porsche         4.042667
# Saab           10.653000
# Saturn         33.770000
# Subaru         40.067500
# Toyota         82.245000
# Volkswagen     34.868667
# Volvo          12.623333
# Name: Sales_in_thousands, dtype: float64

# %%
#Highest Sales Volume
CarSales.groupby('Manufacturer')['Sales_in_thousands'].mean().idxmax()
# Out:
# 'Ford'

# %%
#Checking for the manufacturer with the lowest average sales volume

CarSales.groupby('Manufacturer')['Sales_in_thousands'].mean().idxmin()
# Out:
# 'Porsche'

# %%
#7.Displaying the distribution of car prices in the dataset

pv3 = CarSales.pivot_table(index='Manufacturer', values='Price_in_thousands',aggfunc='sum')
pv3
pv3.plot(kind='hist', figsize=(10,8))
plt.xlabel('Manufacturer')
plt.ylabel('Sum of Prices')
plt.title('Distribution of Car Prices')
plt.show()

# %%
#8. Correlation of Numerical Values in Dataset. 

CarSales_correlation=CarSales.corr()
CarSales_correlation
# Out:
#                     Sales_in_thousands  Year Resale Value  Price_in_thousands  \
# Sales_in_thousands            1.000000          -0.263100           -0.301850
# Year Resale Value            -0.263100           1.000000            0.821509
# Price_in_thousands           -0.301850           0.821509            1.000000
# Engine_size                   0.027716           0.464424            0.623545
# Horsepower                   -0.192519           0.698899            0.841062
# Wheelbase                     0.360186          -0.049046            0.108494
# Width                         0.143664           0.158984            0.328493
# Length                        0.260162           0.022725            0.154924
# Curb_weight                   0.008784           0.298945            0.527148
# Fuel_capacity                 0.087437           0.274457            0.423980
# Fuel_efficiency              -0.016474          -0.357530           -0.491391
# ...

# %%
#Plotting the Correlation matrix

plt.figure(figsize=(10, 8))
sns.heatmap(CarSales_correlation, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %%
#9. Plotting the relationship between price and latest launch year.(Hint: Change Latest_Launch Data Type for linearity of data type)

CarSales.Latest_Launch= CarSales.Latest_Launch.astype('datetime64[ns]')

# %%
#Relationship Between Price and Latest Launch

pv1 = CarSales.pivot_table(index='Latest_Launch', values='Price_in_thousands',aggfunc='sum')
pv1
pv1.plot(kind='line', figsize=(8,4))
plt.xlabel('Latest_Launch')
plt.ylabel('Price_in_thousands')
plt.title('Relationship of Car price and latest launch year')
plt.show()

# %%
#Slicing from Year 2011 to 2013 for more insight into the data

after_2010=CarSales[CarSales['Latest_Launch'] > '01-01-2011']
after_2010
# Out:
#     Manufacturer    Model  Sales_in_thousands  Year Resale Value Vehicle_type  \
# 0          Acura  Integra              16.919          16.360000    Passenger
# 1          Acura       TL              39.384          19.875000    Passenger
# 3          Acura       RL               8.588          29.725000    Passenger
# 4           Audi       A4              20.397          22.255000    Passenger
# 5           Audi       A6              18.780          23.555000    Passenger
# ..           ...      ...                 ...                ...          ...
# 152        Volvo      V40               3.545          18.072975    Passenger
# 153        Volvo      S70              15.245          18.072975    Passenger
# 154        Volvo      V70              17.531          18.072975    Passenger
# 155        Volvo      C70               3.493          18.072975    Passenger
# 156        Volvo      S80              18.969          18.072975    Passenger
#
# ...

# %%
#Question 10
#Grouping Cars By Manufacturers and their Prices

Average_Price=CarSales.groupby('Manufacturer')['Price_in_thousands'].mean()
Average_Price
# Out:
# Manufacturer
# Acura         30.633333
# Audi          39.980000
# BMW           33.096667
# Buick         26.781250
# Cadillac      39.198750
# Chevrolet     20.022778
# Chrysler      23.430833
# Dodge         24.384500
# Ford          21.047273
# Honda         20.277000
# Hyundai       12.165667
# Infiniti      29.465000
# Jaguar        42.800000
# Jeep          20.991667
# Lexus         44.055000
# Lincoln       41.690000
# Mercedes-B    52.916667
# Mercury       20.748333
# Mitsubishi    22.167429
# Nissan        22.360714
# Oldsmobile    25.917400
# Plymouth      22.642500
# Pontiac       22.949167
# Porsche       62.473333
# Saab          29.610000
# Saturn        14.271000
# Subaru        21.395000
# Toyota        21.982889
# Volkswagen    17.698333
# Volvo         30.933333
# Name: Price_in_thousands, dtype: float64

# %%
#Grouping Cars by Manufactures and their fuel efficiency

Average_Fuel_Efficiency=CarSales.groupby('Manufacturer')['Fuel_efficiency'].mean()
Average_Fuel_Efficiency
# Out:
# Manufacturer
# Acura         25.000000
# Audi          23.333333
# BMW           25.000000
# Buick         24.250000
# Cadillac      20.250000
# Chevrolet     28.444444
# Chrysler      24.500000
# Dodge         20.100000
# Ford          22.818182
# Honda         25.000000
# Hyundai       27.666667
# Infiniti      25.000000
# Jaguar        21.000000
# Jeep          18.666667
# Lexus         20.833333
# Lincoln       19.333333
# Mercedes-B    23.444444
# Mercury       23.666667
# Mitsubishi    22.857143
# Nissan        22.285714
# Oldsmobile    23.000000
# Plymouth      25.250000
# Pontiac       24.833333
# Porsche       22.000000
# Saab          23.000000
# Saturn        30.400000
# Subaru        24.500000
# Toyota        25.222222
# Volkswagen    26.166667
# Volvo         24.500000
# Name: Fuel_efficiency, dtype: float64

# %%
#Question 11
#Visualizing the Most Popular car Brands

pv2 = CarSales.pivot_table(index='Manufacturer', values='Sales_in_thousands',aggfunc='sum')
pv2
pv2.plot(kind='bar', figsize=(8,4))
plt.xlabel('Manufacturer')
plt.ylabel('Sales_in_thousands')
plt.title('Most Popular Car Brand')
plt.show()

# %%
#Question 12
#Comparing the Highest resale value with Car Model

Resale_Value=CarSales.groupby('Model')['Year Resale Value'].mean()
Resale_Value
# Out:
# Model
# 3-Sep       18.072975
# 3000GT      20.940000
# 300M        18.072975
# 323i        18.072975
# 328i        28.675000
#               ...
# Viper       58.470000
# Voyager     12.025000
# Windstar    13.175000
# Wrangler    13.475000
# Xterra      18.072975
# Name: Year Resale Value, Length: 151, dtype: float64

# %%
#Extracting the Model with the Highest Year Resale value

CarSales.groupby('Model')['Year Resale Value'].mean().idxmax()
# Out:
# 'Carrera Cabrio'

# %%
#Comparing the Model with the Highest Resale value with it's initial price

pv3 = CarSales.pivot_table(index='Model', values='Price_in_thousands',aggfunc='sum')
pv3
pv3.plot(kind='hist', figsize=(8,4))
plt.xlabel('Model')
plt.ylabel('Price_in_thousands')
plt.title('Resale value VS Initial Price')
plt.show()

# %%
#Question 13
#Finding the top 3 fuel-efficient cars with an engine size greater than 2.5litres (Hint: Filter the variables concerned)

filtering= CarSales[CarSales['Engine_size']>2.5]
filtering
# Out:
#     Manufacturer         Model  Sales_in_thousands  Year Resale Value  \
# 1          Acura            TL              39.384          19.875000
# 3          Acura            RL               8.588          29.725000
# 5           Audi            A6              18.780          23.555000
# 6           Audi            A8               1.380          39.000000
# 8            BMW          328i               9.231          28.675000
# ..           ...           ...                 ...                ...
# 138       Toyota        Avalon              63.849          18.140000
# 141       Toyota        Sienna              65.119          18.072975
# 143       Toyota       4Runner              68.411          19.425000
# 144       Toyota  Land Cruiser               9.835          34.080000
# 156        Volvo           S80              18.969          18.072975
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %%
#Using fuel efficiency, sort the top three
top_three= filtering.sort_values(by='Fuel_efficiency',ascending=False).head(3)
top_three
# Out:
#    Manufacturer        Model  Sales_in_thousands  Year Resale Value  \
# 27    Chevrolet       Impala             107.995          18.072975
# 22    Chevrolet  Monte Carlo              42.593          11.525000
# 98   Mercedes-B    CLK Coupe              11.592          18.072975
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 27    Passenger               18.89          3.4       180.0      110.5
# 22    Passenger               19.39          3.4       180.0      110.5
# 98    Passenger               41.60          3.2       215.0      105.9
#
#     Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 27   73.0   200.0        3.389           17.0             27.0    2011-06-18
# 22   72.7   197.9        3.340           17.0             27.0    2011-12-22
# 98   67.8   180.3        3.213           16.4             26.0    2011-07-08
#
#     Power_perf_factor
# 27          71.838039
# 22          72.030917
# ...

# %%
#Showing the 'top three' model of cars with fuel efficiency

(top_three['Model'])
# Out:
# 27         Impala
# 22    Monte Carlo
# 98      CLK Coupe
# Name: Model, dtype: object

# %%
#Question 14
#Identifying which Lexus Model has the highest horsepower(Hint:Filter the model in the dataset first)
#Filtering the dataset

lexus_model= CarSales[CarSales['Manufacturer']== 'Lexus']
lexus_model
# Out:
#    Manufacturer  Model  Sales_in_thousands  Year Resale Value Vehicle_type  \
# 70        Lexus  ES300              24.072          26.975000    Passenger
# 71        Lexus  GS300              12.698          32.075000    Passenger
# 72        Lexus  GS400               3.334          18.072975    Passenger
# 73        Lexus  LS400               6.375          40.375000    Passenger
# 74        Lexus  LX470               9.126          18.072975          Car
# 75        Lexus  RX300              51.238          18.072975          Car
#
#     Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 70              31.505          3.0       210.0      105.1   70.5   190.2
# 71              37.805          3.0       225.0      110.2   70.9   189.2
# 72              46.305          4.0       300.0      110.2   70.9   189.2
# 73              54.005          4.0       290.0      112.2   72.0   196.7
# ...

# %%
#finding the Lexus Model with the highest horsepower
#Showing the properties of the Lexus Model with the highest horsepower

highest_horsepower= lexus_model.loc[lexus_model['Horsepower'].idxmax()]
highest_horsepower
# Out:
# Manufacturer                        Lexus
# Model                               GS400
# Sales_in_thousands                  3.334
# Year Resale Value               18.072975
# Vehicle_type                    Passenger
# Price_in_thousands                 46.305
# Engine_size                           4.0
# Horsepower                          300.0
# Wheelbase                           110.2
# Width                                70.9
# Length                              189.2
# Curb_weight                         3.693
# Fuel_capacity                        19.8
# Fuel_efficiency                      21.0
# Latest_Launch         2012-11-28 00:00:00
# Power_perf_factor              125.013357
# Name: 72, dtype: object

# %%
#Extracting the name of the model with the highest horsepower
highest_horsepower['Model']
# Out:
# 'GS400'

# %%
###Thank You!!!
